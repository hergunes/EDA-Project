# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df0 = pd.read_csv("adult_eda.csv")
df = df0.copy()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
# Your Code is Here

df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Your Code is Here

df.shape
# Out:
# (32561, 15)

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check if the Dataset have any Duplicate

# Your Code is Here

df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
# Drop Duplicates

# Your Code is Here
df.drop_duplicates(inplace=True)

# df = df.drop_duplicates()

# %%
# Check the shape of the Dataset

# Your Code is Here

df.shape
# Out:
# (32537, 15)

# %%
# Your Code is Here

df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
# Your Code is Here
df.rename({"education-num" : "education_num", "marital-status" : "marital_status", "capital-gain" : "capital_gain",
           "capital-loss" : "capital_loss", "hours-per-week" : "hours_per_week", "native-country" : "native_country",
           "sex":"gender"},
          axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Check the sum of Missing Values per column

# Your Code is Here

df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values

# Your Code is Here

df.isnull().sum()/len(df)*100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# gender            0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
# Your Code is Here
df.columns[df.dtypes=="object"].value_counts()
# Out:
# workclass         1
# education         1
# marital_status    1
# occupation        1
# relationship      1
# race              1
# gender            1
# native_country    1
# salary            1
# dtype: int64

# %%
# Your Code is Here

df.describe(include="object").T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# gender          32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %% [markdown]
# **Assign the Columns (Features) of object data type as** **``"object_col"``**

# %%
# Your Code is Here

object_col = df.select_dtypes(include="object").columns
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'gender', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
# Your Code is Here

#df[df.isin(['?'])].any()
df.isin(['?']).any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# gender            False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
# Your Code is Here
df.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
# Your Code is Here
ax=sns.countplot(x="salary", data=df)
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
# Your Code is Here

df.salary.value_counts(normalize=True)
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
# Your Code is Here

plt.figure(figsize=(10, 8))

colors_list = ['lightskyblue', 'gold']

mylabels = ["<=50K",">50K"]

explode_list = [0,0.1]

size = df.salary.value_counts()

plt.pie(x = size,
        labels = mylabels,
        labeldistance=1.1,
        textprops={'fontsize': 14},
        autopct="%1.1f%%", 
        startangle=0,
        shadow=True,
        colors=colors_list, 
        explode=explode_list)

plt.title("Percentage of Income-Levels",fontsize=15,loc="center")
plt.show()

# %%
#explode = [0, 0.1]

#plt.pie(salary_per, labels=salary_per.index, autopct='%.1f%%', explode=explode, shadow=True )

#plt.title("Percentage of Income-Levels", fontsize="17" )
#plt.legend();

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** 75.9% of individuals earn 50K or less while 24.1% of them earn more than 50K annually.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(df.age);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.histplot(data=df,x="age",kde=True,bins=20);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(df["salary"],df["age"]);

# %%
# Your Code is Here

sns.histplot(data=df,x="age",hue="salary",kde=True,bins=20);

# %%
# Your Code is Here

sns.kdeplot(data=df,x="age",hue="salary",fill=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["age"].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** The age of %50 of the sample is between 28 and 48.
# Extreme values (ages upper 70s and more) are seen on the right side of the boxplot.
# The mean of the age (38.5) is slightly above of the median value (37). This is an indicator of a right-skewed distribution.
# The average age of individuals earning more than 50K is higher than the average age of those earning <=50K.
#
# The number of the people earnig <=50K is higher than the number of people earning >50K in almost every age group except for age around 50. Thıs could be the indicator of people in high-level managerial positions earn more.

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(df.fnlwgt);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(data=df,x="fnlwgt",fill=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(df["salary"],df["fnlwgt"]);

# %%
# Your Code is Here

sns.kdeplot(data=df,x="fnlwgt",hue="salary",fill=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["fnlwgt"].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** According to the boxplot, all extreme values are higher than the max. value.The fnlwgt distribution is right skewed. Mean value is larger than medium value.
#
# The distribution of fnlwgt does not show any serious differences between salary groups. In both group 0.2 has the highest density.
#
# Extreme values reach higher points in people with salary <=50.

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(data=df,x="capital_gain");

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(data=df,x="capital_gain",fill=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(data=df,x="salary",y="capital_gain");

# %%
# Your Code is Here

sns.kdeplot(data=df,x="capital_gain",hue="salary",fill=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["capital_gain"].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
df[df.capital_gain!=0].groupby("salary")["capital_gain"].describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :Capital gain is mostly zero for total sample. All zero values belong to <=50K.
#
# For the group >50K capital gain starts over from zero and ranges within a narrower gap.
#
# The number of people with positive capital gain is larger in the >50K, although their number is lower than <=50K in total group.
#
# So we can say that people earning more have more capital gain.

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
df.capital_loss.value_counts()
# Out:
# 0       31018
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: capital_loss, Length: 92, dtype: int64

# %%
# Your Code is Here

sns.boxplot(data=df,x="capital_loss");

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(data=df,x="capital_loss",fill=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(data=df,x="salary",y="capital_loss");

# %%
# Your Code is Here

sns.kdeplot(data=df,x="capital_loss",hue="salary",fill=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["capital_loss"].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here

df[df.capital_loss!=0].groupby("salary")["capital_loss"].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# Result :Important number of the group does not have capital loss.
#
# On the other hand, capital loss figures for whole group is mainly between 1500 and 2600.
#
# Capital loss for people with >50K generally has lost larger amount of money.

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(data=df,x="hours_per_week");

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(data=df,x="hours_per_week",fill=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(data=df,x="salary",y="hours_per_week");

# %%
# Your Code is Here

sns.kdeplot(data=df,x="hours_per_week",hue="salary",fill=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["hours_per_week"].describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# There is an important number of extreme values at the both sides of the boxplot, representing values lower than min. and bigger than max.
#
# Average working hours for a week is 40.4 and this is almost equal to median, 40.Density of working hours more than 40 is higher than lower 40 hours.
#
# While there are extreme or potential outliers, people earning more than 50K works more than people with <50K. The more work brings more money.
#
# Density for >50K is lower than <=50K  for same working hours. The reason for this could be the position they have.

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
# Your Code is Here

sns.pairplot(data=df,hue="salary",corner=True,palette="viridis");

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# Your Code is Here

df.education_num.value_counts(dropna=False)
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
# Your Code is Here

df.groupby("education")["education_num"].value_counts(dropna=False)
#df.groupby(["education","education_num"], dropna=False)["education_num"].count()
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="education")

ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
# Your Code is Here

sns.countplot(data=df,x="education_num");

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here

df.groupby("education")["salary"].value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="education",hue="salary")

ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
# Your Code is Here

df.groupby("education_num")["salary"].value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
# Your Code is Here

sns.countplot(data=df,x="education_num",hue="salary");

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(data=df,x="salary",y="education_num");

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# Your Code is Here

df["education"].apply(mapping_education).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"

# Your Code is Here

df['education_summary'] = df['education'].map(mapping_education)

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
# Your Code is Here

sns.countplot(data=df,x="education_summary");

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="education_summary",hue="salary");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("education_summary")["salary"].value_counts(normalize=True)
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=3,figsize=(15,8))

mylabel1= ["<=50K",">50K"]
mylabel2= ["<=50K",">50K"]
mylabel3= ["<=50K",">50K"]

axs[0].pie(df.groupby("education_summary")["salary"].value_counts(normalize=True)["high_level_grade"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[0].set_title("high_level_grade",fontsize=15)
axs[0].set_ylabel("salary")

axs[1].pie(df.groupby("education_summary")["salary"].value_counts(normalize=True)["low_level_grade"],labels=mylabel2,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[1].set_title("low_level_grade",fontsize=15)
axs[1].set_ylabel("salary")

axs[2].pie(df.groupby("education_summary")["salary"].value_counts(normalize=True)["medium_level_grade"],labels=mylabel2,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[2].set_title("medium_level_grade",fontsize=15)
axs[2].set_ylabel("salary")

plt.show()

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="salary",hue="education_summary");

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["education_summary"].value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(12,8))

mylabel1= ["(<=50K,medium_level_grade)","(<=50K,high_level_grade)","(<=50K,low_level_grade)"]
mylabel2=[ "(>50K,high_level_grade)","(>50K,medium_level_grade)","(>50K,low_level_grade)"]
axs[0].pie(df.groupby("salary")["education_summary"].value_counts(normalize=True)["<=50K"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[0].set_title("<=50K")
axs[0].set_ylabel("education_summary")

axs[1].pie(df.groupby("salary")["education_summary"].value_counts(normalize=True)[">50K"],labels=mylabel2,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[1].set_title(">50K")
axs[1].set_ylabel("education_summary")

plt.show()

# %%
# Your Code is Here

df1 =df.groupby("salary")["education_summary"].value_counts(normalize=True).sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"education_summary":"percantage"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#   salary   education_summary  percantage
# 0  <=50K    high_level_grade       0.168
# 1  <=50K     low_level_grade       0.162
# 2  <=50K  medium_level_grade       0.670
# 3   >50K    high_level_grade       0.499
# 4   >50K     low_level_grade       0.031
# 5   >50K  medium_level_grade       0.470

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(12,8))

mylabel1= ["medium","high","low"]
mylabel2=[ "high","medium","low"]
axs[0].pie(df.groupby("salary")["education_summary"].value_counts(normalize=True)["<=50K"],labels=mylabel1,autopct="%1.2f%%",colors = ['lightgreen', 'lightblue','pink'],counterclock=False)
axs[0].set_title("<=50K")
axs[0].set_ylabel("percentage")

axs[1].pie(df.groupby("salary")["education_summary"].value_counts(normalize=True)[">50K"],labels=mylabel2,autopct="%1.2f%%",colors = ['pink', 'lightgreen','lightblue'],startangle=180)
axs[1].set_title(">50K")
axs[1].set_ylabel("percentage")

plt.show()

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Education level of the sample ranges from preschool to Phd Level. Main education levels are high school (9 years), some college (10 years), and bachelors (13 years). In each education level,it is possible to see people from both salary group.
# Except for the three highest education years (Phd, Prof-Schools, and Masters) the number of people earning less than
# <=50K is higher than other group. While there are extreme education years for <=50 K, education years for >50K is in a narrower gap. Extreme values for this group relatively less.
#
# We can conclude that people with higher education level likely have a higher salary level.

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# Your Code is Here

df.relationship.value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here

df.relationship.fillna("Unknown", inplace=True)

# %%
# Your Code is Here

df.groupby("relationship")["marital_status"].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
# ...

# %% [markdown]
# **Assessment :** The largest group of the sample by marital status is married men.

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
ax=sns.countplot(df.marital_status)
ax.set_xticklabels(df.marital_status.unique(),rotation=45);

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="marital_status")

ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="marital_status",hue="salary")

ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# Your Code is Here

df["marital_status"].apply(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

# Your Code is Here

df["marital_status_summary"] = df["marital_status"].map(mapping_marital_status)

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
# Your Code is Here

sns.countplot(data=df,x="marital_status_summary");

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="marital_status_summary",hue="salary");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15,8))

mylabel1= ["<=50K",">50K"]
mylabel2= ["<=50K",">50K"]

axs[0].pie(df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)["married"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue'])
axs[0].set_title("married",fontsize=15)
axs[0].set_ylabel("salary")

axs[1].pie(df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)["unmarried"],labels=mylabel2,autopct="%1.2f%%",colors = ['pink', 'lightblue'])
axs[1].set_title("unmarried",fontsize=15)
axs[1].set_ylabel("salary")



plt.show()

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["marital_status_summary"].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="salary",hue="marital_status_summary");

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
# Your Code is Here

df1 =df.groupby("salary")["marital_status_summary"].value_counts(normalize=True).sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"marital_status_summary":"percantage"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#   salary marital_status_summary  percantage
# 0  <=50K                married       0.351
# 1  <=50K              unmarried       0.649
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15,8))

mylabel1= ["unmarried","married"]
mylabel2= ["married","unmarried"]

axs[0].pie(df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)["<=50K"],labels=mylabel1,autopct="%1.2f%%",colors = ['lightblue', 'pink'],counterclock=False)
axs[0].set_title("<=50K",fontsize=15)
axs[0].set_ylabel("percentage")

axs[1].pie(df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)[">50K"],labels=mylabel2,autopct="%1.2f%%",colors = ['pink', 'lightblue'])
axs[1].set_title(">50K",fontsize=15)
axs[1].set_ylabel("percentage")



plt.show()

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Earning >50K is more common among married people. In other words, more than 85% of the >50K salary group is married. Without considering other indicators such as the number of how many years passed in marriage or age, we can say that people with higher salary are more ready yo marriage.

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="workclass")

ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here

df.workclass.replace("?", "Unknown", inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="workclass",hue="salary");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
# Your Code is Here

df1 =df.groupby("workclass")["salary"].value_counts(normalize=True).sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"salary":"percantage"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#            workclass salary  percantage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc  <=50K       0.443
# 8       Self-emp-inc   >50K       0.557
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
# Your Code is Here

ax = sns.barplot(data=df1,x="workclass",y="percantage",hue="salary")


for i in ax.containers:
    ax.bar_label(i,fmt="%1.2f")
    
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="salary",hue="workclass");

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here

df1 =df.groupby("salary")["workclass"].value_counts(normalize=True).sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"workclass":"percantage"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#    salary         workclass  percantage
# 0   <=50K       Federal-gov       0.024
# 1   <=50K         Local-gov       0.060
# 2   <=50K      Never-worked       0.000
# 3   <=50K           Private       0.717
# 4   <=50K      Self-emp-inc       0.020
# 5   <=50K  Self-emp-not-inc       0.074
# 6   <=50K         State-gov       0.038
# 7   <=50K           Unknown       0.067
# 8   <=50K       Without-pay       0.001
# 9    >50K       Federal-gov       0.047
# 10   >50K         Local-gov       0.079
# 11   >50K           Private       0.633
# 12   >50K      Self-emp-inc       0.079
# 13   >50K  Self-emp-not-inc       0.092
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %%
# Your Code is Here

plt.figure(figsize=(18,8))

ax = sns.barplot(data=df1,x="salary",y="percantage",hue="workclass")

for i in ax.containers:
    ax.bar_label(i,fmt="%1.3f")

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**Most of the sample work in the private sector. Because of this, the number of people for two salary groups mainly from this sector. However, the percentage of >50K is larger in self-employed inc and federal government.

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="occupation")

ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df.occupation.replace("?", "Unknown", inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="occupation",hue="salary")

ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("occupation")["salary"].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
# Your Code is Here

df1 =df.groupby("occupation")["salary"].value_counts(normalize=True).sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"salary":"percantage"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#            occupation salary  percantage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
# Your Code is Here

ax = sns.barplot(data=df1,x="occupation",y="percantage",hue="salary")

for i in ax.containers:
    ax.bar_label(i,fmt="%1.2f")
    
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["occupation"].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
# Your Code is Here

sns.countplot(data=df,x="salary",hue="occupation");

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("salary")["occupation"].value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
# Your Code is Here

df1 =df.groupby("salary")["occupation"].value_counts(normalize=True).sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"occupation":"percantage"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#    salary         occupation  percantage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Armed-Forces       0.000
# 2   <=50K       Craft-repair       0.128
# 3   <=50K    Exec-managerial       0.085
# 4   <=50K    Farming-fishing       0.036
# 5   <=50K  Handlers-cleaners       0.052
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K      Other-service       0.128
# 8   <=50K    Priv-house-serv       0.006
# 9   <=50K     Prof-specialty       0.092
# 10  <=50K    Protective-serv       0.018
# 11  <=50K              Sales       0.108
# 12  <=50K       Tech-support       0.026
# 13  <=50K   Transport-moving       0.052
# 14  <=50K            Unknown       0.067
# 15   >50K       Adm-clerical       0.065
# 16   >50K       Armed-Forces       0.000
# 17   >50K       Craft-repair       0.119
# 18   >50K    Exec-managerial       0.251
# 19   >50K    Farming-fishing       0.015
# 20   >50K  Handlers-cleaners       0.011
# 21   >50K  Machine-op-inspct       0.032
# ...

# %%
# Your Code is Here

plt.figure(figsize=(18,8))

ax = sns.barplot(data=df1,x="salary",y="percantage",hue="occupation")

for i in ax.containers:
    ax.bar_label(i,fmt="%1.3f")

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Managerial positions and prof-speciality jobs are the jobs having most probability to earn more money.

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df.race.value_counts(normalize=True)
# Out:
# White                0.854
# Black                0.096
# Asian-Pac-Islander   0.032
# Amer-Indian-Eskimo   0.010
# Other                0.008
# Name: race, dtype: float64

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="race")

ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("race")["salary"].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="race",hue="salary")

ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby("race")["salary"].value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=2,ncols=3,figsize=(18,8))

mylabel1= ["<=50K",">50K"]


axs[0,0].pie(df.groupby("race")["salary"].value_counts(normalize=True)["Amer-Indian-Eskimo"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[0,0].set_title("Amer-Indian-Eskimo",fontsize=15)
axs[0,0].set_ylabel("salary")

axs[0,1].pie(df.groupby("race")["salary"].value_counts(normalize=True)["Asian-Pac-Islander"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[0,1].set_title("Asian-Pac-Islander",fontsize=15)
axs[0,1].set_ylabel("salary")

axs[0,2].pie(df.groupby("race")["salary"].value_counts(normalize=True)["Black"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[0,2].set_title("Black",fontsize=15)
axs[0,2].set_ylabel("salary")

axs[1,0].pie(df.groupby("race")["salary"].value_counts(normalize=True)["Other"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[1,0].set_title("Other",fontsize=15)
axs[1,0].set_ylabel("salary")

axs[1,1].pie(df.groupby("race")["salary"].value_counts(normalize=True)["White"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue','lightgreen'])
axs[1,1].set_title("White",fontsize=15)
axs[1,1].set_ylabel("salary")

axs[1,2].axis("off")

plt.show()

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["race"].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="salary",hue="race");

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("salary")["race"].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
# Your Code is Here

df1 =df.groupby("salary")["race"].value_counts(normalize=True).sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"race":"percantage"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#   salary                race  percantage
# 0  <=50K  Amer-Indian-Eskimo       0.011
# 1  <=50K  Asian-Pac-Islander       0.031
# 2  <=50K               Black       0.111
# 3  <=50K               Other       0.010
# 4  <=50K               White       0.837
# 5   >50K  Amer-Indian-Eskimo       0.005
# 6   >50K  Asian-Pac-Islander       0.035
# 7   >50K               Black       0.049
# 8   >50K               Other       0.003
# 9   >50K               White       0.908

# %%
# Your Code is Here

plt.figure(figsize=(18,8))

ax = sns.barplot(data=df1,x="salary",y="percantage",hue="race")

for i in ax.containers:
    ax.bar_label(i,fmt="%1.3f")

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Among the races, Asian Pasific Islander has 3% of the population and has the biggest percentage of earning more. White people has a slightly lower percentage.

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
# Your Code is Here

df.gender.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: gender, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="gender");

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("gender")["salary"].value_counts()
# Out:
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="gender",hue="salary");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby("gender")["salary"].value_counts(normalize=True)
# Out:
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15,8))

mylabel1= ["<=50K",">50K"]


axs[0].pie(df.groupby("gender")["salary"].value_counts(normalize=True)["Female"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink','lightblue'])
axs[0].set_title("Female",fontsize=15)
axs[0].set_ylabel("percentage")

axs[1].pie(df.groupby("gender")["salary"].value_counts(normalize=True)["Male"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue'])
axs[1].set_title("Male",fontsize=15)
axs[1].set_ylabel("percentage")



plt.show()

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["gender"].value_counts()
# Out:
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: gender, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="salary",hue="gender");

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby("salary")["gender"].value_counts(normalize=True)
# Out:
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: gender, dtype: float64

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15,8))

mylabel1= ["Male","Female"]


axs[0].pie(df.groupby("salary")["gender"].value_counts(normalize=True)["<=50K"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink','lightblue'])
axs[0].set_title("<=50K",fontsize=15)
axs[0].set_ylabel("gender")

axs[1].pie(df.groupby("salary")["gender"].value_counts(normalize=True)[">50K"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue'])
axs[1].set_title(">50K",fontsize=15)
axs[1].set_ylabel("gender")



plt.show()

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Men earns more money than female.

# %% [markdown]
# ### native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
# Your Code is Here

ax = sns.countplot(data=df,x="native_country")

ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df.native_country.replace("?", "Unknown", inplace=True)

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# Your Code is Here

df["native_country"].apply(mapping_native_country).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

# Your Code is Here

df["native_country_summary"] = df["native_country"].map(mapping_native_country)
df.native_country_summary
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here

sns.countplot(data=df,x="native_country_summary");

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("native_country_summary")["salary"].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="native_country_summary",hue="salary");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15,8))

mylabel1= ["<=50K",">50K"]


axs[0].pie(df.groupby("native_country_summary")["salary"].value_counts(normalize=True)["Others"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink','lightblue'])
axs[0].set_title("Others",fontsize=15)
axs[0].set_ylabel("salary")

axs[1].pie(df.groupby("native_country_summary")["salary"].value_counts(normalize=True)["US"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue'])
axs[1].set_title("US",fontsize=15)
axs[1].set_ylabel("salary")



plt.show()

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["native_country_summary"].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here

sns.countplot(data=df,x="salary",hue="native_country_summary");

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(15,8))

mylabel1= ["US","Others"]


axs[0].pie(df.groupby("salary")["native_country_summary"].value_counts(normalize=True)["<=50K"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink','lightblue'])
axs[0].set_title("<=50K",fontsize=15)
axs[0].set_ylabel("native_country_summary")

axs[1].pie(df.groupby("salary")["native_country_summary"].value_counts(normalize=True)[">50K"],labels=mylabel1,autopct="%1.2f%%",colors = ['pink', 'lightblue'])
axs[1].set_title(">50K",fontsize=15)
axs[1].set_ylabel("native_country_summary")



plt.show()

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**  Both salary group has similar levels for US or outside US people. In other words, the native country of the people does not cause an important difference in salary level.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
# Your Code is Here

df.groupby(["salary","gender"])["age"].mean()
# Out:
# salary  gender
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
# Your Code is Here

ax = df.groupby(["salary","gender"])["age"].mean().plot(kind="bar")

ax.bar_label(ax.containers[0]);

# %%
# Your Code is Here

df1 =df.groupby(["salary","gender"])["age"].mean().sort_index()
df1= pd.DataFrame(df1)
df1.rename(columns={"age":"age"},inplace=True)
df1.reset_index(inplace=True)
df1
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
# Your Code is Here

ax = sns.barplot(data=df,x="salary",y="age",hue="gender",ci=None)


for i in ax.containers:
    ax.bar_label(i,fmt="%1.2f%%")

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
# Your Code is Here

df.loc[(df['salary'] == '>50K') & (df["native_country_summary"]== "US"),'workclass'].value_counts(normalize=True) * 100
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
# Your Code is Here

ax = (df.loc[(df['salary'] == '>50K') & (df["native_country_summary"]== "US"),'workclass'].value_counts(normalize=True)*100).plot.bar(color=["blue","orange","green","red","purple","brown","pink"])

for i in ax.containers:
    ax.bar_label(i,fmt="%1.2f")
    
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
# Your Code is Here

df.loc[(df['workclass'] == 'Private') & (df['salary'] == '>50K') & (df["native_country_summary"]== "US"),'occupation'].value_counts(normalize=True) * 100
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
# Your Code is Here

ax = (df.loc[(df['workclass'] == 'Private') & (df['salary'] == '>50K') & (df["native_country_summary"]== "US"),'occupation'].value_counts(normalize=True)*100).plot.bar(color=["blue","orange","green","red","purple","brown","pink"])

for i in ax.containers:
    ax.bar_label(i,fmt="%1.2f")

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
# Your Code is Here

df.loc[(df['salary'] == '>50K') & (df["race"]== "Asian-Pac-Islander"),'education'].value_counts(normalize=True) * 100
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
# Your Code is Here

ax = (df.loc[(df['salary'] == '>50K') & (df["race"]== "Asian-Pac-Islander"),'education'].value_counts(normalize=True) * 100).plot.bar(color=["blue","orange","green","red","purple","brown","pink"])

for i in ax.containers:
    ax.bar_label(i,fmt="%1.2f")

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# Your Code is Here

df.loc[(df['salary'] == '>50K') &(df["education"]=="Bachelors") & (df["race"]== "Asian-Pac-Islander"),'occupation'].value_counts(normalize=True) * 100
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
# Your Code is Here

ax = (df.loc[(df['salary'] == '>50K') &(df["education"]=="Bachelors") & (df["race"]== "Asian-Pac-Islander"),'occupation'].value_counts(normalize=True) * 100).plot.bar(color=["blue","orange","green","red","purple","brown","pink"])

for i in ax.containers:
    ax.bar_label(i,fmt="%1.2f")

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
# Your Code is Here

g = sns.catplot(data=df,
           x="education_summary",
           y="hours_per_week",
           kind="bar",
           col="marital_status_summary",
           row="native_country_summary",
           hue="gender",
           ci=None,
           palette="RdPu",
           )

g.fig.set_size_inches(15, 8)
g.fig.subplots_adjust(top=0.9)



g.fig.suptitle('Working Hours Per Week Gender for Education,Workclass,Marital Status')

for ax in g.axes.ravel():
    
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here

df.drop(['education', 'education_num', 'relationship', 'marital_status', 'native_country'], axis=1, inplace=True)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here

df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

df.loc[(df.workclass=="Unknown")|(df.workclass=="Never-worked"), "workclass"].value_counts()
# Out:
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

df.replace(to_replace = "Unknown", value = np.nan, inplace = True)

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here

df.dropna(inplace=True)

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

sns.boxplot(data=df);

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=2,ncols=3,figsize=(18,8))


sns.boxplot(data=df,x="age",ax=axs[0,0])

sns.boxplot(data=df,x="fnlwgt",ax= axs[0,1])

sns.boxplot(data=df,x="capital_gain",ax = axs[0,2])

sns.boxplot(data=df,x="capital_loss",ax=axs[1,0])

sns.boxplot(data=df,x="hours_per_week",ax= axs[1,1])

axs[1,2].axis("off")

plt.show()

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

fig,axs = plt.subplots(nrows=5,ncols=2,figsize=(18,10))


sns.boxplot(data=df,x="age",ax= axs[0,0])
sns.histplot(data=df,x="age",ax= axs[0,1])

sns.boxplot(data=df,x="fnlwgt",ax=axs[1,0])
sns.histplot(data=df,x="fnlwgt",bins=120,ax=axs[1,1])

sns.boxplot(data=df,x="capital_gain",ax=axs[2,0])
sns.histplot(data=df,x="capital_gain",ax=axs[2,1])


sns.boxplot(data=df,x="capital_loss",ax=axs[3,0])
sns.histplot(data=df,x="capital_loss",ax=axs[3,1])

sns.boxplot(data=df,x="hours_per_week",ax=axs[4,0])
sns.histplot(data=df,x="hours_per_week",ax=axs[4,1])



plt.show()

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here

df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            30694.000     38.448     13.115    17.000     28.000
# fnlwgt         30694.000 189848.229 105465.126 13769.000 117828.500
# capital_gain   30694.000   1106.902   7500.730     0.000      0.000
# capital_loss   30694.000     88.980    405.808     0.000      0.000
# hours_per_week 30694.000     40.953     11.984     1.000     40.000
#
#                       50%        75%         max
# age                37.000     47.000      90.000
# fnlwgt         178513.500 237293.750 1484705.000
# capital_gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

fig,axs = plt.subplots(1,2)

sns.boxplot(data=df,y="age",ax=axs[0])
sns.histplot(data=df,x="age",ax=axs[1])

plt.show()

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here
from scipy import stats

low_level = df.age.quantile(0.25)
high_level = df.age.quantile(0.75)
IQR = high_level - low_level
print(low_level, high_level,IQR)
# Out:
# 28.0 47.0 19.0

# %%
# Find lower and upper limit using IQR

# Your Code is Here

lower_lim = low_level - 1.5*IQR
upper_lim = high_level + 1.5*IQR
lower_lim, upper_lim
# Out:
# (-0.5, 75.5)

# %%
# Your Code is Here

df[df.age > upper_lim].age.value_counts()
# Out:
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here

df[(df["age"]>upper_lim)].sort_values(by="age",ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8806    90           Private   87372   Prof-specialty               White
# 14159   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28463   90       Federal-gov  195433     Craft-repair               White
# 12975   90           Private  250832  Exec-managerial               White
# 11996   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15102   76         Local-gov  169133     Adm-clerical               White
# 19085   76           Private  125784  Exec-managerial               White
# 23515   76           Private  142535     Adm-clerical               White
# 8240    76  Self-emp-not-inc  225964            Sales               White
# 23354   76           Private  199949     Adm-clerical               White
#
#        gender  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

fig,axs = plt.subplots(1,2)

sns.boxplot(data=df,y="hours_per_week",ax=axs[0])
sns.histplot(data=df,x="hours_per_week",ax=axs[1],bins=10)

plt.show()

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

low_level = df.hours_per_week.quantile(0.25)
high_level = df.hours_per_week.quantile(0.75)
IQR = high_level - low_level

low_level,high_level,IQR
# Out:
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here

lower_lim = low_level - 1.5*IQR
upper_lim = high_level + 1.5*IQR
lower_lim, upper_lim
# Out:
# (32.5, 52.5)

# %%
# Your Code is Here

df[df.hours_per_week > upper_lim].hours_per_week.value_counts().sort_index(ascending=False)
# Out:
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here

df[(df["hours_per_week"]>upper_lim)].sort_values(by="hours_per_week",ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation   race  gender  \
# 25986   44         Local-gov  212665   Protective-serv  Black    Male
# 19529   38           Private   66326  Transport-moving  White    Male
# 8796    39           Private   70995  Transport-moving  White    Male
# 15534   29           Private  167716     Other-service  White  Female
# 22313   26  Self-emp-not-inc  258306   Farming-fishing  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 1138    27           Private  138705      Craft-repair  White    Male
# 23244   58           Private  248739   Farming-fishing  White    Male
# 28858   62           Private  123411  Transport-moving  White    Male
# 18417   24           Private  117167     Other-service  White  Female
# 31622   61  Self-emp-not-inc  268831             Sales  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
# Your Code is Here

df[df.hours_per_week < lower_lim].hours_per_week.value_counts().sort_index()
# Out:
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here

df[df.hours_per_week < lower_lim].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4372.000 21.548 7.343 1.000 16.000 20.000 30.000 32.000
# >50K    322.000 22.028 7.813 1.000 18.000 24.000 30.000 32.000

# %%
# Your Code is Here

df[df.hours_per_week < lower_lim].groupby("salary")["age"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  4372.000 34.052 17.730 17.000 20.000 26.000 45.000 90.000
# >50K    322.000 49.484 13.894 22.000 39.000 48.000 60.000 90.000

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here

df2 = df[(df["age"]>80)].sort_values(by="age",ascending=False)
df2
# Out:
#        age     workclass  fnlwgt       occupation   race  gender  \
# 222     90       Private   51744    Other-service  Black    Male
# 18832   90       Private  115306  Exec-managerial  White  Female
# 10545   90       Private  175491     Craft-repair  White    Male
# 11512   90       Private   87285    Other-service  White  Female
# 11996   90       Private   40388  Exec-managerial  White    Male
# ...    ...           ...     ...              ...    ...     ...
# 19045   81     State-gov  132204    Other-service  White  Female
# 6748    81       Private  122651            Sales  White    Male
# 2906    81       Private  114670  Priv-house-serv  Black  Female
# 21501   81       Private  177408  Exec-managerial  White    Male
# 19495   81  Self-emp-inc  247232  Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 222               0          2206              40  <=50K  medium_level_grade
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here

df2.shape
# Out:
# (76, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here

df2_index = df2.index
df2_index
# Out:
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
# Drop these indices defined above for age

# Your Code is Here

df.drop(df2_index, inplace=True)

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here
df[(df.hours_per_week<7)|(df.hours_per_week>70)].sort_values(by="hours_per_week",ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 22216   45           Private   54260      Craft-repair               White
# 5432    44           Private   83508    Prof-specialty               White
# 19053   27           Private   40295  Transport-moving               White
# 19141   59           Private  106748     Other-service               White
# 19399   39      Self-emp-inc  163057      Craft-repair               White
# ...    ...               ...     ...               ...                 ...
# 20909   77  Self-emp-not-inc   71676      Adm-clerical               White
# 25078   74           Private  260669     Other-service               White
# 19750   23           Private   72887      Craft-repair  Asian-Pac-Islander
# 189     58         State-gov  109567    Prof-specialty               White
# 24284   57  Self-emp-not-inc   56480   Exec-managerial               White
#
#        gender  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here


df3 = df[(df.hours_per_week<7)|(df.hours_per_week>70)].sort_values(by="hours_per_week",ascending=False)
df3.shape
# Out:
# (621, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

df3.index
# Out:
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

df3_index = df3.index
df.drop(df3_index,axis=0, inplace=True)

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

df[(df["age"]>60) & (df["hours_per_week"]>60)]
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 1541    62           Private  162245    Prof-specialty               White
# 2154    75           Private  101887   Priv-house-serv               White
# 2184    63      Self-emp-inc   54052             Sales               White
# 2665    70           Private   94692             Sales               White
# 3101    65      Self-emp-inc   81413   Farming-fishing               White
# 5417    67           Private  197816             Sales               White
# 6826    68           Private  284763  Transport-moving               White
# 8066    61  Self-emp-not-inc  133969             Sales  Asian-Pac-Islander
# 9646    62  Self-emp-not-inc   26911     Other-service               White
# 12624   63      Self-emp-inc  110890    Prof-specialty               White
# 16634   62  Self-emp-not-inc  115176   Farming-fishing               White
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here

df[(df["age"]>60) & (df["hours_per_week"]>60)].shape
# Out:
# (23, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here

df4 = df[(df["age"]>60) & (df["hours_per_week"]>60)]
df4.index
# Out:
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here

df4_index = df4.index
df.drop(df4_index,axis=0, inplace=True)

# %%
# What is new shape of dataframe now

# Your Code is Here

df.shape
# Out:
# (29974, 13)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here

df.reset_index(inplace=True,drop=True)
df.head()
# Out:
#    age         workclass  fnlwgt         occupation   race  gender  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# 2             0             0              40  <=50K  medium_level_grade
# 3             0             0              40  <=50K     low_level_grade
# 4             0             0              40  <=50K    high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here

df["salary"]=df["salary"].map({"<=50K":0,">50K":1})
df.salary
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

df.salary.value_counts()
# Out:
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# Your Code is Here

df_final = pd.get_dummies(df,drop_first=True)
df_final
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week  salary  \
# 0       39   77516          2174             0              40       0
# 1       50   83311             0             0              13       0
# 2       38  215646             0             0              40       0
# 3       53  234721             0             0              40       0
# 4       28  338409             0             0              40       0
# ...    ...     ...           ...           ...             ...     ...
# 29969   27  257302             0             0              38       0
# 29970   40  154374             0             0              40       1
# 29971   58  151910             0             0              40       0
# 29972   22  201490             0             0              20       0
# 29973   52  287927         15024             0              40       1
#
#        workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# ...

# %%
# What's the shape of dataframe

# Your Code is Here

df.shape
# Out:
# (29974, 13)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

df_final.shape
# Out:
# (29974, 34)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here

df_final.corr()
# Out:
#                                         age  fnlwgt  capital_gain  \
# age                                   1.000  -0.074         0.082
# fnlwgt                               -0.074   1.000        -0.002
# capital_gain                          0.082  -0.002         1.000
# capital_loss                          0.059  -0.011        -0.032
# hours_per_week                        0.119  -0.019         0.086
# salary                                0.253  -0.010         0.222
# workclass_Local-gov                   0.070  -0.004        -0.010
# workclass_Private                    -0.211   0.045        -0.045
# workclass_Self-emp-inc                0.111  -0.025         0.093
# workclass_Self-emp-not-inc            0.146  -0.037         0.033
# workclass_State-gov                   0.020  -0.012        -0.013
# workclass_Without-pay                 0.016  -0.003        -0.002
# occupation_Armed-Forces              -0.011   0.004        -0.003
# ...

# %%
# Your Code is Here

plt.figure(figsize=(20,12))

sns.heatmap(df_final.corr(),annot=True,cmap="YlGnBu",fmt=".2g");

# %%
# Your Code is Here

df_final.corr()[["salary"]].sort_values(by="salary",ascending=False).drop("salary",axis=0)
# Out:
#                                       salary
# age                                    0.253
# hours_per_week                         0.247
# capital_gain                           0.222
# gender_Male                            0.216
# occupation_Exec-managerial             0.215
# occupation_Prof-specialty              0.185
# capital_loss                           0.152
# workclass_Self-emp-inc                 0.138
# race_White                             0.086
# native_country_summary_US              0.035
# workclass_Self-emp-not-inc             0.030
# workclass_Local-gov                    0.029
# occupation_Protective-serv             0.026
# occupation_Tech-support                0.023
# occupation_Sales                       0.015
# race_Asian-Pac-Islander                0.012
# workclass_State-gov                    0.011
# occupation_Armed-Forces               -0.006
# fnlwgt                                -0.010
# workclass_Without-pay                 -0.012
# ...

# %%
df_salary = df_final.corr()[["salary"]].sort_values(by="salary",ascending=False).drop("salary",axis=0)

# %%
# Your Code is Here

plt.figure(figsize=(2,10))

sns.heatmap(df_salary,annot=True,cmap="YlGnBu");

# %%
# Your Code is Here

plt.figure(figsize=(8,12))

df_salary["salary"].sort_values().plot.barh();

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
